# %% [markdown]
# <a href="https://colab.research.google.com/github/marconunesjr/CursoJs/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = pd.read_json('/content/dados_hospedagem.json')
dados.head()

# %%
dados = pd.json_normalize(dados['info_moveis'])
dados
